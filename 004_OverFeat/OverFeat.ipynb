# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# c:\IDEA\OverFeat

# %%
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms, datasets
from torch.utils.data import Dataset, DataLoader

from torchsummaryX import summary
from tensorboardX import SummaryWriter

# %%
print(torch.__version__)

device = ("cuda" if torch.cuda.is_available() else "cpu") # device 정의
print(device)
# Out:
# 1.10.2+cu113
# cuda

# %%
torch.cuda.get_device_name()
# Out:
# 'NVIDIA GeForce RTX 3080'

# %%
class OverFeat_accurate(nn.Module):
    def __init__(self, num_classes=1000):
        super().__init__()

        # train with 221x221 5 random crops and their horizontal filps
        # mini- batches of size 128
        # initialized weight randomly with mu=0, sigma=1x10^-2
        # SGD, momentum=0.6, l2 weight decay of 1x10^-5
        # learning rate 5x10^-2, decay by 0.5 after (30, 50, 60, 70, 80) epochs
        # Dropout on FCN?? -> dropout before classifier conv layer

        self.feature_extractor = nn.Sequential(
            # no contrast normalization is used
            # max polling with non-overlapping
            # 1st and 2nd layer stride 2 instead of 4

            # 1st
            nn.Conv2d(in_channels=3, out_channels=96, kernel_size=7, stride=2),  # (b x 96 x 108 x 108)
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=3),  # (b x 96 x 36 x 36)

            # 2nd
            nn.Conv2d(96, 256, 7, stride= 1),  # (b x 256 x 30 x 30)
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),  # (b x 256 x 15 x 15)

            # 3rd
            nn.Conv2d(256, 512, 3, padding=1),  # (b x 512 x 15 x 15)
            nn.ReLU(),

            # 4th
            nn.Conv2d(512, 512, 3, padding=1),  # (b x 512 x 15 x 15)
            nn.ReLU(),

            # 5th
            nn.Conv2d(512, 1024, 3, padding=1),  # (b x 1024 x 15 x 15)
            nn.ReLU(),

            # 6th
            nn.Conv2d(1024, 1024, 3, padding=1),  # (b x 1024 x 15 x 15)
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=3),  # (b x 1024 x 5 x 5)
        )

        # fully connecyed layers implemented as a convolution layers
        self.classifier = nn.Sequential(
            # 7th
            nn.Dropout(p=0.5, inplace=True),
            nn.Conv2d(in_channels=1024, out_channels=4096, kernel_size=5),
            nn.ReLU(),

            # 8th
            nn.Dropout(p=0.5, inplace=True),
            nn.Conv2d(4096, 4096, 1),
            nn.ReLU(),

            # 9th
            nn.Conv2d(4096, num_classes, 1)
        )

        self.init_weight()  # initialize weight

    def init_weight(self):
        for layer in self.feature_extractor:
            if isinstance(layer, nn.Conv2d):
                nn.init.normal_(layer.weight, mean=0, std=0.01)

    def forward(self, x):
        """
        Pass the input through the net.
        Args:
            x (Tensor): input tensor
        Returns:
            output (Tensor): output tensor
        """
        x = self.feature_extractor(x)
        return self.classifier(x).squeeze()

# %%
class OverFeat_fast(nn.Module):
    def __init__(self, num_classes=1000):
        super().__init__()

        # train with 221x221 5 random crops and their horizontal filps
        # mini- batches of size 128
        # initialized weight randomly with mu=0, sigma=1x10^-2
        # SGD, momentum=0.6, l2 weight decay of 1x10^-5
        # learning rate 5x10^-2, decay by 0.5 after (30, 50, 60, 70, 80) epochs
        # Dropout on FCN?? -> dropout before classifier conv layer

        self.feature_extractor = nn.Sequential(
            # no contrast normalization is used
            # max polling with non-overlapping
            # 1st and 2nd layer stride 2 instead of 4

            # 1st
            nn.Conv2d(in_channels=3, out_channels=96, kernel_size=11, stride=4),  # (b x 96 x 56 x 56)
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),  # (b x 96 x 28 x 28)

            # 2nd
            nn.Conv2d(96, 256, 5, stride= 1),  # (b x 256 x 24 x 24)
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),  # (b x 256 x 12 x 12)

            # 3rd
            nn.Conv2d(256, 512, 3, padding=1),  # (b x 512 x 12 x 12)
            nn.ReLU(),

            # 4th
            nn.Conv2d(512, 1024, 3, padding=1),  # (b x 1024 x 12 x 12)
            nn.ReLU(),

            # 5th
            nn.Conv2d(1024, 1024, 3, padding=1),  # (b x 1024 x 12 x 12)
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),  # (b x 1024 x 6 x 6)
        )

        # fully connecyed layers implemented as a convolution layers
        self.classifier = nn.Sequential(
            # 6th
            nn.Dropout(p=0.5, inplace=False),
            nn.Conv2d(in_channels=1024, out_channels=3072, kernel_size=6),
            nn.ReLU(),

            # 7th
            nn.Dropout(p=0.5, inplace=False),
            nn.Conv2d(3072, 4096, 1),
            nn.ReLU(),

            # 8th
            nn.Conv2d(4096, num_classes, 1)
        )

        self.init_weight()  # initialize weight

    def init_weight(self):
        for layer in self.feature_extractor:
            if isinstance(layer, nn.Conv2d):
                nn.init.normal_(layer.weight, mean=0, std=0.01)

    def forward(self, x):
        """
        Pass the input through the net.
        Args:
            x (Tensor): input tensor
        Returns:
            output (Tensor): output tensor
        """
        x = self.feature_extractor(x)
        return self.classifier(x).squeeze()

# %%
path_img_train = "../ILSVRC2012/ILSVRC2012_img_train/"
path_img_val = "../ILSVRC2012/ILSVRC2012_img_val/"

path_log = "tblog/"
path_checkpoint = "checkpoints/"
if not(os.path.exists(path_log)):
    os.makedirs(path_log)
if not(os.path.exists(path_checkpoint)):
    os.makedirs(path_checkpoint)

# %%
seed = torch.initial_seed()
print(f'Used seed : {seed}')
# Out:
# Used seed : 25335229804900

# %%
tbwriter = SummaryWriter(log_dir=path_log)

# %%
Fast = True

num_epochs = 100
batch_size = 128

# %%
if(Fast):
    overfeat = OverFeat_fast(num_classes=1000).to(device)
    summary(overfeat, torch.zeros((128,3,231,231),device=device))
else:
    overfeat = OverFeat_accurate(num_classes=1000).to(device)
    summary(overfeat, torch.zeros((128,3,221,221),device=device))

# overfeat = torch.nn.parallel.DataParallel(overfeat, device_ids=)
# Out:
# =====================================================================================================
#                                          Kernel Shape         Output Shape  \
# Layer
# 0_feature_extractor.Conv2d_0          [3, 96, 11, 11]    [128, 96, 56, 56]
# 1_feature_extractor.ReLU_1                          -    [128, 96, 56, 56]
# 2_feature_extractor.MaxPool2d_2                     -    [128, 96, 28, 28]
# 3_feature_extractor.Conv2d_3          [96, 256, 5, 5]   [128, 256, 24, 24]
# 4_feature_extractor.ReLU_4                          -   [128, 256, 24, 24]
# 5_feature_extractor.MaxPool2d_5                     -   [128, 256, 12, 12]
# 6_feature_extractor.Conv2d_6         [256, 512, 3, 3]   [128, 512, 12, 12]
# 7_feature_extractor.ReLU_7                          -   [128, 512, 12, 12]
# 8_feature_extractor.Conv2d_8        [512, 1024, 3, 3]  [128, 1024, 12, 12]
# 9_feature_extractor.ReLU_9                          -  [128, 1024, 12, 12]
# 10_feature_extractor.Conv2d_10     [1024, 1024, 3, 3]  [128, 1024, 12, 12]
# 11_feature_extractor.ReLU_11                        -  [128, 1024, 12, 12]
# 12_feature_extractor.MaxPool2d_12                   -    [128, 1024, 6, 6]
# 13_classifier.Dropout_0                             -    [128, 1024, 6, 6]
# 14_classifier.Conv2d_1             [1024, 3072, 6, 6]    [128, 3072, 1, 1]
# 15_classifier.ReLU_2                                -    [128, 3072, 1, 1]
# 16_classifier.Dropout_3                             -    [128, 3072, 1, 1]
# 17_classifier.Conv2d_4             [3072, 4096, 1, 1]    [128, 4096, 1, 1]
# 18_classifier.ReLU_5                                -    [128, 4096, 1, 1]
# 19_classifier.Conv2d_6             [4096, 1000, 1, 1]    [128, 1000, 1, 1]
#
#                                        Params     Mult-Adds
# Layer
# 0_feature_extractor.Conv2d_0          34.944k   109.283328M
# 1_feature_extractor.ReLU_1                  -             -
# 2_feature_extractor.MaxPool2d_2             -             -
# 3_feature_extractor.Conv2d_3         614.656k     353.8944M
# 4_feature_extractor.ReLU_4                  -             -
# 5_feature_extractor.MaxPool2d_5             -             -
# 6_feature_extractor.Conv2d_6         1.18016M   169.869312M
# 7_feature_extractor.ReLU_7                  -             -
# 8_feature_extractor.Conv2d_8        4.719616M   679.477248M
# 9_feature_extractor.ReLU_9                  -             -
# 10_feature_extractor.Conv2d_10      9.438208M  1.358954496G
# 11_feature_extractor.ReLU_11                -             -
# 12_feature_extractor.MaxPool2d_12           -             -
# 13_classifier.Dropout_0                     -             -
# 14_classifier.Conv2d_1             113.24928M   113.246208M
# 15_classifier.ReLU_2                        -             -
# 16_classifier.Dropout_3                     -             -
# 17_classifier.Conv2d_4             12.587008M    12.582912M
# 18_classifier.ReLU_5                        -             -
# 19_classifier.Conv2d_6                 4.097M        4.096M
# -----------------------------------------------------------------------------------------------------
#                             Totals
# Total params           145.920872M
# Trainable params       145.920872M
# Non-trainable params           0.0
# Mult-Adds             2.801403904G
# =====================================================================================================
# C:\Anaconda3\envs\IDEA_torch\lib\site-packages\torchsummaryX\torchsummaryX.py:101: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_sum = df.sum()

# %%
if(Fast):
    cropsize = 231
else:
    cropsize = 221

# %%
dataset_train = datasets.ImageFolder(path_img_train, transforms.Compose([
    transforms.Resize(256),
    transforms.RandomCrop(cropsize),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor()
]))
dataset_val = datasets.ImageFolder(path_img_val, transforms.Compose([
    transforms.Resize(256),
    transforms.RandomCrop(cropsize),
    transforms.ToTensor()
]))

# %%
dataloader_train = DataLoader(
    dataset=dataset_train,
    batch_size=batch_size,
    shuffle=True,
    num_workers=6,
    pin_memory=True,
    drop_last=True
)
dataloader_val = DataLoader(
    dataset=dataset_val,
    batch_size=batch_size,
    shuffle=True,
    num_workers=6,
    pin_memory=True,
    drop_last=True
)

# %%
optimizer = optim.SGD(
    params=overfeat.parameters(),
    momentum=0.6,
    weight_decay=1e-5,
    lr=5e-2
)

lr_scheduler = optim.lr_scheduler.MultiStepLR(optimizer=optimizer, milestones=[30, 50, 60, 70, 80], gamma=0.5)

# %%
overfeat.train()
step = 1

for epoch in range(num_epochs):
    for imgs, classes in dataloader_train:
        imgs, classes = imgs.to(device), classes.to(device)

        output = overfeat(imgs)
        loss = F.cross_entropy(output, classes)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()


        if(step % 1e3 == 0):
            with torch.no_grad():
                _, preds = torch.max(output, 1)
                accuracy = torch.sum(preds == classes)

                print(f'Epoch: {epoch + 1} \tStep: {step} \tLoss: {loss.item():.4f} \tAcc: {accuracy.item()}')
                tbwriter.add_scalar('loss', loss.item(), step)
                tbwriter.add_scalar('accuracy', accuracy.item(), step)

                for name, parameter in overfeat.named_parameters():
                    if parameter.grad is not None:
                        avg_grad = torch.mean(parameter.grad)
                        # print(f'\t{name} - grad_avg: {avg_grad}')
                        tbwriter.add_scalar(f'grad_avg/{name}', avg_grad.item(), step)
                        tbwriter.add_histogram(f'grad/{name}', parameter.grad.cpu().numpy(), step)
                    if parameter.data is not None:
                        avg_weight = torch.mean(parameter.data)
                        # print(f'\t{name} - param_avg: {avg_weight}')
                        tbwriter.add_histogram(f'weight/{name}', parameter.data.cpu().numpy(), step)
                        tbwriter.add_scalar(f'weight_avg/{name}', avg_weight.item(), step)

                overfeat.eval()
                val_cLoss = 0
                val_cAcc = 0
                val_count = 0
                
                for val_imgs, val_classes in dataloader_val:
                    val_imgs, val_classes = val_imgs.to(device), val_classes.to(device)

                    val_output = overfeat(val_imgs)
                    val_cLoss += F.cross_entropy(val_output, val_classes)

                    _, val_pred = torch.max(val_output, 1)
                    val_cAcc += torch.sum(val_pred == val_classes)

                    val_count += 1

                val_loss = val_cLoss / val_count
                val_accuracy = val_cAcc / val_count

                print(f'\tValidation Loss: {val_loss:.4f} \t Validation Acc: {val_cAcc} / {val_count} ({val_accuracy.item()*100:0f}%)')
                tbwriter.add_scalar('val_loss', val_loss.item(), step)
                tbwriter.add_scalar('val_accuracy', val_accuracy.item(), step)
                overfeat.train()

        step += 1
        
    lr_scheduler.step()
    
    if(Fast):
        checkpoint_path = os.path.join(path_checkpoint, f'overfeat_fast_states_epoch{epoch}.pkl')
    else:
        checkpoint_path = os.path.join(path_checkpoint, f'overfeat_accurate_states_epoch{epoch}.pkl')
    state = {
        'epoch': epoch,
        'step': step,
        'optimizer': optimizer.state_dict(),
        'model': overfeat.state_dict(),
        'seed' : seed
    }
    torch.save(state, checkpoint_path)
# Out:
# Epoch: 1 	Step: 1000 	Loss: 6.9073 	Acc: 0
# 	Validation Loss: 6.907937526702881 	 Validation Acc: 0.12564103305339813
# Epoch: 1 	Step: 2000 	Loss: 6.9111 	Acc: 0
# 	Validation Loss: 6.908069610595703 	 Validation Acc: 0.12820513546466827
# Epoch: 1 	Step: 3000 	Loss: 6.9077 	Acc: 0
# 	Validation Loss: 6.907866954803467 	 Validation Acc: 0.13076923787593842
# Epoch: 1 	Step: 4000 	Loss: 6.8437 	Acc: 0
# 	Validation Loss: 6.836755752563477 	 Validation Acc: 0.34358975291252136
# Epoch: 1 	Step: 5000 	Loss: 6.7401 	Acc: 0
# 	Validation Loss: 6.7239556312561035 	 Validation Acc: 0.4615384638309479
# Epoch: 1 	Step: 6000 	Loss: 6.6208 	Acc: 0
# 	Validation Loss: 6.631789684295654 	 Validation Acc: 0.7307692766189575
# Epoch: 1 	Step: 7000 	Loss: 6.4837 	Acc: 2
# 	Validation Loss: 6.435487747192383 	 Validation Acc: 1.3615385293960571
# Epoch: 1 	Step: 8000 	Loss: 6.1081 	Acc: 4
# 	Validation Loss: 6.164587497711182 	 Validation Acc: 2.797435998916626
# Epoch: 1 	Step: 9000 	Loss: 5.9132 	Acc: 2
# 	Validation Loss: 5.841606616973877 	 Validation Acc: 4.400000095367432
# Epoch: 1 	Step: 10000 	Loss: 5.4375 	Acc: 4
# 	Validation Loss: 5.567022800445557 	 Validation Acc: 6.528205394744873
# Epoch: 2 	Step: 11000 	Loss: 5.2425 	Acc: 10
# 	Validation Loss: 5.243900775909424 	 Validation Acc: 9.253846168518066
# Epoch: 2 	Step: 12000 	Loss: 5.1766 	Acc: 9
# 	Validation Loss: 5.118107318878174 	 Validation Acc: 10.338461875915527
# Epoch: 2 	Step: 13000 	Loss: 4.9591 	Acc: 8
# 	Validation Loss: 4.864896297454834 	 Validation Acc: 13.730770111083984
# Epoch: 2 	Step: 14000 	Loss: 4.6627 	Acc: 11
# 	Validation Loss: 4.75720739364624 	 Validation Acc: 14.779487609863281
# Epoch: 2 	Step: 15000 	Loss: 4.5741 	Acc: 22
# 	Validation Loss: 4.713809013366699 	 Validation Acc: 16.015384674072266
# Epoch: 2 	Step: 16000 	Loss: 4.4066 	Acc: 17
# 	Validation Loss: 4.4393181800842285 	 Validation Acc: 19.143590927124023
# Epoch: 2 	Step: 17000 	Loss: 4.4908 	Acc: 16
# 	Validation Loss: 4.33642578125 	 Validation Acc: 21.092308044433594
# Epoch: 2 	Step: 18000 	Loss: 4.2070 	Acc: 28
# 	Validation Loss: 4.270925998687744 	 Validation Acc: 21.738462448120117
# Epoch: 2 	Step: 19000 	Loss: 4.2041 	Acc: 25
# 	Validation Loss: 4.213897705078125 	 Validation Acc: 22.612821578979492
# Epoch: 2 	Step: 20000 	Loss: 4.1630 	Acc: 25
# 	Validation Loss: 4.1470208168029785 	 Validation Acc: 24.230770111083984
# Epoch: 3 	Step: 21000 	Loss: 3.8747 	Acc: 32
# 	Validation Loss: 4.051483154296875 	 Validation Acc: 25.707693099975586
# Epoch: 3 	Step: 22000 	Loss: 3.8167 	Acc: 26
# 	Validation Loss: 3.9588518142700195 	 Validation Acc: 27.058975219726562
# Epoch: 3 	Step: 23000 	Loss: 3.6016 	Acc: 33
# 	Validation Loss: 3.897613525390625 	 Validation Acc: 27.88461685180664
# Epoch: 3 	Step: 24000 	Loss: 4.0948 	Acc: 28
# 	Validation Loss: 3.874865770339966 	 Validation Acc: 28.666667938232422
# Epoch: 3 	Step: 25000 	Loss: 3.9059 	Acc: 22
# 	Validation Loss: 3.762455940246582 	 Validation Acc: 30.85641098022461
# Epoch: 3 	Step: 26000 	Loss: 3.5757 	Acc: 41
# 	Validation Loss: 3.740926504135132 	 Validation Acc: 31.169231414794922
# Epoch: 3 	Step: 27000 	Loss: 3.4475 	Acc: 35
# 	Validation Loss: 3.684041976928711 	 Validation Acc: 32.089744567871094
# Epoch: 3 	Step: 28000 	Loss: 3.7223 	Acc: 27
# 	Validation Loss: 3.5909502506256104 	 Validation Acc: 34.17692565917969
# Epoch: 3 	Step: 29000 	Loss: 3.6676 	Acc: 40
# 	Validation Loss: 3.589111328125 	 Validation Acc: 34.584617614746094
# Epoch: 3 	Step: 30000 	Loss: 3.7621 	Acc: 30
# 	Validation Loss: 3.569106340408325 	 Validation Acc: 34.18717956542969
# Epoch: 4 	Step: 31000 	Loss: 3.7111 	Acc: 39
# 	Validation Loss: 3.5201048851013184 	 Validation Acc: 35.35128402709961
# Epoch: 4 	Step: 32000 	Loss: 3.0804 	Acc: 44
# 	Validation Loss: 3.509024143218994 	 Validation Acc: 35.52564239501953
# Epoch: 4 	Step: 33000 	Loss: 3.3204 	Acc: 38
# 	Validation Loss: 3.451206684112549 	 Validation Acc: 36.623077392578125
# Epoch: 4 	Step: 34000 	Loss: 3.6332 	Acc: 35
# 	Validation Loss: 3.466766595840454 	 Validation Acc: 36.75128173828125
# Epoch: 4 	Step: 35000 	Loss: 3.4782 	Acc: 34
# 	Validation Loss: 3.385321617126465 	 Validation Acc: 37.62820816040039
# Epoch: 4 	Step: 36000 	Loss: 3.0739 	Acc: 45
# 	Validation Loss: 3.3661434650421143 	 Validation Acc: 38.394874572753906
# Epoch: 4 	Step: 37000 	Loss: 3.3100 	Acc: 32
# 	Validation Loss: 3.3438594341278076 	 Validation Acc: 39.012821197509766
# Epoch: 4 	Step: 38000 	Loss: 3.2528 	Acc: 51
# 	Validation Loss: 3.326077461242676 	 Validation Acc: 39.07179641723633
# Epoch: 4 	Step: 39000 	Loss: 3.0329 	Acc: 43
# 	Validation Loss: 3.308516263961792 	 Validation Acc: 39.838462829589844
# Epoch: 4 	Step: 40000 	Loss: 3.1784 	Acc: 41
# 	Validation Loss: 3.283264636993408 	 Validation Acc: 40.5384635925293
# Epoch: 5 	Step: 41000 	Loss: 3.2611 	Acc: 45
# 	Validation Loss: 3.231943368911743 	 Validation Acc: 41.07179641723633
# Epoch: 5 	Step: 42000 	Loss: 2.9794 	Acc: 43
# 	Validation Loss: 3.214480400085449 	 Validation Acc: 41.21282196044922
# Epoch: 5 	Step: 43000 	Loss: 3.4658 	Acc: 48
# 	Validation Loss: 3.2531211376190186 	 Validation Acc: 41.012821197509766
# Epoch: 5 	Step: 44000 	Loss: 3.0679 	Acc: 51
# 	Validation Loss: 3.23235821723938 	 Validation Acc: 41.22051239013672
# Epoch: 5 	Step: 45000 	Loss: 2.9629 	Acc: 41
# 	Validation Loss: 3.200868606567383 	 Validation Acc: 42.143592834472656
# Epoch: 5 	Step: 46000 	Loss: 3.3433 	Acc: 43
# 	Validation Loss: 3.1602606773376465 	 Validation Acc: 43.0435905456543
# Epoch: 5 	Step: 47000 	Loss: 3.0792 	Acc: 47
# 	Validation Loss: 3.160086154937744 	 Validation Acc: 42.66410446166992
# Epoch: 5 	Step: 48000 	Loss: 3.4113 	Acc: 43
# 	Validation Loss: 3.1922597885131836 	 Validation Acc: 42.32564163208008
# Epoch: 5 	Step: 49000 	Loss: 3.0836 	Acc: 40
# 	Validation Loss: 3.1123666763305664 	 Validation Acc: 44.0359001159668
# Epoch: 5 	Step: 50000 	Loss: 3.0580 	Acc: 48
# 	Validation Loss: 3.171335458755493 	 Validation Acc: 42.19743728637695
# Epoch: 6 	Step: 51000 	Loss: 3.1488 	Acc: 36
# 	Validation Loss: 3.081411600112915 	 Validation Acc: 44.615386962890625
# Epoch: 6 	Step: 52000 	Loss: 3.2094 	Acc: 42
# 	Validation Loss: 3.1174700260162354 	 Validation Acc: 43.653846740722656
# Epoch: 6 	Step: 53000 	Loss: 3.2369 	Acc: 44
# 	Validation Loss: 3.082676649093628 	 Validation Acc: 44.46923065185547
# Epoch: 6 	Step: 54000 	Loss: 3.0736 	Acc: 39
# 	Validation Loss: 3.061690330505371 	 Validation Acc: 44.758975982666016
# Epoch: 6 	Step: 55000 	Loss: 2.7211 	Acc: 54
# 	Validation Loss: 3.0819239616394043 	 Validation Acc: 44.56410217285156
# Epoch: 6 	Step: 56000 	Loss: 3.1057 	Acc: 39
# 	Validation Loss: 3.071606159210205 	 Validation Acc: 44.725643157958984
# Epoch: 6 	Step: 57000 	Loss: 3.3842 	Acc: 38
# 	Validation Loss: 3.064566135406494 	 Validation Acc: 44.70769500732422
# Epoch: 6 	Step: 58000 	Loss: 3.1226 	Acc: 38
# 	Validation Loss: 3.0325894355773926 	 Validation Acc: 45.876922607421875
# Epoch: 6 	Step: 59000 	Loss: 2.8155 	Acc: 48
# 	Validation Loss: 3.017228364944458 	 Validation Acc: 45.758975982666016
# Epoch: 6 	Step: 60000 	Loss: 3.0292 	Acc: 46
# 	Validation Loss: 3.045863151550293 	 Validation Acc: 45.21794891357422
# Epoch: 7 	Step: 61000 	Loss: 2.8912 	Acc: 41
# 	Validation Loss: 2.99174427986145 	 Validation Acc: 46.71025848388672
# Epoch: 7 	Step: 62000 	Loss: 2.8711 	Acc: 49
# 	Validation Loss: 3.0187947750091553 	 Validation Acc: 45.974361419677734
# Epoch: 7 	Step: 63000 	Loss: 2.8435 	Acc: 56
# 	Validation Loss: 2.9874026775360107 	 Validation Acc: 46.17948913574219
# Epoch: 7 	Step: 64000 	Loss: 2.9432 	Acc: 48
# 	Validation Loss: 3.000581979751587 	 Validation Acc: 45.897438049316406
# Epoch: 7 	Step: 65000 	Loss: 3.1573 	Acc: 44
# 	Validation Loss: 3.0248398780822754 	 Validation Acc: 45.60512924194336
# Epoch: 7 	Step: 66000 	Loss: 2.8821 	Acc: 48
# 	Validation Loss: 3.021258592605591 	 Validation Acc: 46.06410217285156
# Epoch: 7 	Step: 67000 	Loss: 2.9963 	Acc: 49
# 	Validation Loss: 3.0338008403778076 	 Validation Acc: 45.874359130859375
# Epoch: 7 	Step: 68000 	Loss: 2.8579 	Acc: 42
# 	Validation Loss: 2.9566168785095215 	 Validation Acc: 47.012821197509766
# Epoch: 7 	Step: 69000 	Loss: 3.0815 	Acc: 37
# 	Validation Loss: 3.0284223556518555 	 Validation Acc: 45.85384750366211
# Epoch: 7 	Step: 70000 	Loss: 2.8336 	Acc: 48
# 	Validation Loss: 3.0182011127471924 	 Validation Acc: 46.05897521972656
# Epoch: 8 	Step: 71000 	Loss: 2.8073 	Acc: 51
# 	Validation Loss: 2.9524030685424805 	 Validation Acc: 47.43589782714844
# Epoch: 8 	Step: 72000 	Loss: 2.7499 	Acc: 47
# 	Validation Loss: 2.953385591506958 	 Validation Acc: 47.223079681396484
# Epoch: 8 	Step: 73000 	Loss: 3.0683 	Acc: 43
# 	Validation Loss: 2.962498426437378 	 Validation Acc: 47.22051239013672
# Epoch: 8 	Step: 74000 	Loss: 2.7211 	Acc: 48
# 	Validation Loss: 2.943370819091797 	 Validation Acc: 47.587181091308594
# Epoch: 8 	Step: 75000 	Loss: 2.6755 	Acc: 48
# 	Validation Loss: 2.934532642364502 	 Validation Acc: 48.06666946411133
# Epoch: 8 	Step: 76000 	Loss: 3.2290 	Acc: 40
# 	Validation Loss: 2.96708607673645 	 Validation Acc: 47.06410217285156
# Epoch: 8 	Step: 77000 	Loss: 2.9861 	Acc: 48
# 	Validation Loss: 2.934893846511841 	 Validation Acc: 47.866668701171875
# Epoch: 8 	Step: 78000 	Loss: 2.7992 	Acc: 49
# 	Validation Loss: 2.9212214946746826 	 Validation Acc: 48.34615707397461
# Epoch: 8 	Step: 79000 	Loss: 2.9122 	Acc: 48
# 	Validation Loss: 2.91750431060791 	 Validation Acc: 48.094871520996094
# Epoch: 8 	Step: 80000 	Loss: 2.7516 	Acc: 54
# 	Validation Loss: 2.9302382469177246 	 Validation Acc: 47.77179718017578
# Epoch: 9 	Step: 81000 	Loss: 2.9546 	Acc: 44
# 	Validation Loss: 2.9344966411590576 	 Validation Acc: 47.830772399902344
# Epoch: 9 	Step: 82000 	Loss: 2.7314 	Acc: 48
# 	Validation Loss: 2.9485280513763428 	 Validation Acc: 47.720516204833984
# Epoch: 9 	Step: 83000 	Loss: 2.9649 	Acc: 48
# 	Validation Loss: 2.897822618484497 	 Validation Acc: 48.52307891845703
# Epoch: 9 	Step: 84000 	Loss: 2.8587 	Acc: 52
# 	Validation Loss: 2.9121851921081543 	 Validation Acc: 48.17436218261719
# Epoch: 9 	Step: 85000 	Loss: 2.7079 	Acc: 54
# 	Validation Loss: 2.9267735481262207 	 Validation Acc: 48.19487380981445
# Epoch: 9 	Step: 86000 	Loss: 3.2074 	Acc: 43
# 	Validation Loss: 2.969458818435669 	 Validation Acc: 47.5333366394043
# Epoch: 9 	Step: 87000 	Loss: 3.0422 	Acc: 46
# 	Validation Loss: 2.9517109394073486 	 Validation Acc: 47.67436218261719
# Epoch: 9 	Step: 88000 	Loss: 2.6943 	Acc: 54
# 	Validation Loss: 2.948615074157715 	 Validation Acc: 47.70513153076172
# Epoch: 9 	Step: 89000 	Loss: 2.6857 	Acc: 53
# 	Validation Loss: 2.902247667312622 	 Validation Acc: 48.77179718017578
# Epoch: 9 	Step: 90000 	Loss: 2.8546 	Acc: 56
# 	Validation Loss: 2.9367516040802 	 Validation Acc: 47.66666793823242
# Epoch: 10 	Step: 91000 	Loss: 2.7555 	Acc: 52
# 	Validation Loss: 2.8886325359344482 	 Validation Acc: 49.02820587158203
# Epoch: 10 	Step: 92000 	Loss: 3.0134 	Acc: 42
# 	Validation Loss: 2.989722490310669 	 Validation Acc: 47.27179718017578
# Epoch: 10 	Step: 93000 	Loss: 2.5828 	Acc: 51
# 	Validation Loss: 2.9113147258758545 	 Validation Acc: 48.67692565917969
# Epoch: 10 	Step: 94000 	Loss: 2.7559 	Acc: 48
# 	Validation Loss: 2.9096767902374268 	 Validation Acc: 48.43333435058594
# Epoch: 10 	Step: 95000 	Loss: 2.5885 	Acc: 51
# 	Validation Loss: 2.888322114944458 	 Validation Acc: 49.13077163696289
# Epoch: 10 	Step: 96000 	Loss: 2.8940 	Acc: 52
# 	Validation Loss: 2.9020862579345703 	 Validation Acc: 49.11025619506836
# Epoch: 10 	Step: 97000 	Loss: 2.7476 	Acc: 51
# 	Validation Loss: 2.8821659088134766 	 Validation Acc: 49.32051467895508
# Epoch: 10 	Step: 98000 	Loss: 2.6105 	Acc: 54
# 	Validation Loss: 2.8896963596343994 	 Validation Acc: 49.27948760986328
# Epoch: 10 	Step: 99000 	Loss: 2.9900 	Acc: 48
# 	Validation Loss: 2.939180612564087 	 Validation Acc: 47.80769348144531
# Epoch: 10 	Step: 100000 	Loss: 3.2845 	Acc: 41
# 	Validation Loss: 2.8976869583129883 	 Validation Acc: 48.64102554321289
# Epoch: 11 	Step: 101000 	Loss: 2.8788 	Acc: 47
# 	Validation Loss: 2.8806912899017334 	 Validation Acc: 49.123077392578125
# Epoch: 11 	Step: 102000 	Loss: 2.8594 	Acc: 46
# 	Validation Loss: 2.922015428543091 	 Validation Acc: 48.28974533081055
# Epoch: 11 	Step: 103000 	Loss: 2.5123 	Acc: 58
# 	Validation Loss: 2.9277050495147705 	 Validation Acc: 48.23846435546875
# Epoch: 11 	Step: 104000 	Loss: 2.9852 	Acc: 41
# 	Validation Loss: 2.9078996181488037 	 Validation Acc: 48.63077163696289
# Epoch: 11 	Step: 105000 	Loss: 2.7230 	Acc: 53
# 	Validation Loss: 2.9412925243377686 	 Validation Acc: 47.92820739746094
# Epoch: 11 	Step: 106000 	Loss: 3.1298 	Acc: 42
# 	Validation Loss: 2.9443747997283936 	 Validation Acc: 48.13589859008789
# Epoch: 11 	Step: 107000 	Loss: 3.0492 	Acc: 45
# 	Validation Loss: 2.9357683658599854 	 Validation Acc: 47.735897064208984
# Epoch: 11 	Step: 108000 	Loss: 2.9764 	Acc: 47
# 	Validation Loss: 2.8991129398345947 	 Validation Acc: 49.002567291259766
# Epoch: 11 	Step: 109000 	Loss: 2.9977 	Acc: 42
# 	Validation Loss: 2.9324915409088135 	 Validation Acc: 48.17948913574219
# Epoch: 11 	Step: 110000 	Loss: 2.7200 	Acc: 47
# 	Validation Loss: 2.9249444007873535 	 Validation Acc: 48.25128173828125
# Epoch: 12 	Step: 111000 	Loss: 2.8509 	Acc: 55
# 	Validation Loss: 2.960582733154297 	 Validation Acc: 47.77948760986328
# Epoch: 12 	Step: 112000 	Loss: 3.0174 	Acc: 44
# 	Validation Loss: 2.907688856124878 	 Validation Acc: 48.66923141479492
# Epoch: 12 	Step: 113000 	Loss: 2.8573 	Acc: 54
# 	Validation Loss: 2.9776134490966797 	 Validation Acc: 47.371795654296875
# Epoch: 12 	Step: 114000 	Loss: 3.2018 	Acc: 40
# 	Validation Loss: 2.9775021076202393 	 Validation Acc: 47.153846740722656
# Epoch: 12 	Step: 115000 	Loss: 3.4181 	Acc: 38
# 	Validation Loss: 2.921757936477661 	 Validation Acc: 48.366668701171875
# Epoch: 12 	Step: 116000 	Loss: 2.6916 	Acc: 49
# 	Validation Loss: 2.9142136573791504 	 Validation Acc: 48.57948684692383
# Epoch: 12 	Step: 117000 	Loss: 3.0005 	Acc: 46
# 	Validation Loss: 2.935540199279785 	 Validation Acc: 48.228206634521484
# Epoch: 12 	Step: 118000 	Loss: 2.7042 	Acc: 48
# 	Validation Loss: 2.8638229370117188 	 Validation Acc: 49.81282043457031
# Epoch: 12 	Step: 119000 	Loss: 2.8319 	Acc: 48
# 	Validation Loss: 2.9511775970458984 	 Validation Acc: 47.91538619995117
# Epoch: 12 	Step: 120000 	Loss: 3.0801 	Acc: 45
# 	Validation Loss: 2.9057273864746094 	 Validation Acc: 48.902565002441406
# Epoch: 13 	Step: 121000 	Loss: 2.8316 	Acc: 49
# 	Validation Loss: 2.89790678024292 	 Validation Acc: 49.015384674072266
# Epoch: 13 	Step: 122000 	Loss: 2.5638 	Acc: 57
# 	Validation Loss: 2.9004430770874023 	 Validation Acc: 48.9461555480957
# Epoch: 13 	Step: 123000 	Loss: 2.7561 	Acc: 58
# 	Validation Loss: 2.972743034362793 	 Validation Acc: 47.620513916015625
# Epoch: 13 	Step: 124000 	Loss: 2.9207 	Acc: 54
# 	Validation Loss: 2.9009764194488525 	 Validation Acc: 48.894874572753906
# Epoch: 13 	Step: 125000 	Loss: 2.9214 	Acc: 43
# 	Validation Loss: 2.9747233390808105 	 Validation Acc: 47.24615478515625
# Epoch: 13 	Step: 126000 	Loss: 3.2359 	Acc: 39
# 	Validation Loss: 3.0212831497192383 	 Validation Acc: 46.405128479003906
# Epoch: 13 	Step: 127000 	Loss: 3.0402 	Acc: 46
# 	Validation Loss: 2.9126060009002686 	 Validation Acc: 48.5384635925293
# Epoch: 13 	Step: 128000 	Loss: 2.8296 	Acc: 48
# 	Validation Loss: 2.9302146434783936 	 Validation Acc: 48.35641098022461
# Epoch: 13 	Step: 129000 	Loss: 2.9868 	Acc: 42
# 	Validation Loss: 2.9162144660949707 	 Validation Acc: 48.85384750366211
# Epoch: 13 	Step: 130000 	Loss: 2.7904 	Acc: 47
# 	Validation Loss: 2.9393110275268555 	 Validation Acc: 48.089744567871094
# Epoch: 14 	Step: 131000 	Loss: 2.5287 	Acc: 49
# 	Validation Loss: 2.933192253112793 	 Validation Acc: 48.16923141479492
# Epoch: 14 	Step: 132000 	Loss: 2.7882 	Acc: 48
# 	Validation Loss: 2.914201021194458 	 Validation Acc: 48.69487380981445
# Epoch: 14 	Step: 133000 	Loss: 2.6679 	Acc: 55
# 	Validation Loss: 3.127931594848633 	 Validation Acc: 44.74871826171875
# Epoch: 14 	Step: 134000 	Loss: 2.7814 	Acc: 51
# 	Validation Loss: 2.9418814182281494 	 Validation Acc: 48.623077392578125
# Epoch: 14 	Step: 135000 	Loss: 3.2593 	Acc: 35
# 	Validation Loss: 2.9457147121429443 	 Validation Acc: 48.18205261230469
# Epoch: 14 	Step: 136000 	Loss: 2.8921 	Acc: 53
# 	Validation Loss: 2.9342501163482666 	 Validation Acc: 48.235897064208984
# Epoch: 14 	Step: 137000 	Loss: 2.8968 	Acc: 48
# 	Validation Loss: 2.9260387420654297 	 Validation Acc: 48.68974685668945
# Epoch: 14 	Step: 138000 	Loss: 2.8812 	Acc: 50
# 	Validation Loss: 2.904555559158325 	 Validation Acc: 48.74871826171875
# Epoch: 14 	Step: 139000 	Loss: 2.7252 	Acc: 53
# 	Validation Loss: 2.9410767555236816 	 Validation Acc: 48.20256423950195
# Epoch: 14 	Step: 140000 	Loss: 2.8701 	Acc: 54
# 	Validation Loss: 2.9635608196258545 	 Validation Acc: 47.78718185424805
# Epoch: 15 	Step: 141000 	Loss: 2.9489 	Acc: 44
# 	Validation Loss: 3.001856565475464 	 Validation Acc: 47.17436218261719
# Epoch: 15 	Step: 142000 	Loss: 3.1051 	Acc: 42
# 	Validation Loss: 2.986684799194336 	 Validation Acc: 47.494873046875
# Epoch: 15 	Step: 143000 	Loss: 2.7910 	Acc: 51
# 	Validation Loss: 2.976290702819824 	 Validation Acc: 47.39230728149414
# Epoch: 15 	Step: 144000 	Loss: 3.1332 	Acc: 47
# 	Validation Loss: 2.8978166580200195 	 Validation Acc: 49.256412506103516
# Epoch: 15 	Step: 145000 	Loss: 2.4149 	Acc: 57
# 	Validation Loss: 2.9346120357513428 	 Validation Acc: 48.28718185424805
# Epoch: 15 	Step: 146000 	Loss: 3.4223 	Acc: 40
# 	Validation Loss: 3.02044939994812 	 Validation Acc: 46.651283264160156
# Epoch: 15 	Step: 147000 	Loss: 3.4024 	Acc: 37
# 	Validation Loss: 3.085841417312622 	 Validation Acc: 45.28974533081055
# Epoch: 15 	Step: 148000 	Loss: 2.8254 	Acc: 45
# 	Validation Loss: 2.9228150844573975 	 Validation Acc: 48.24615478515625
# Epoch: 15 	Step: 149000 	Loss: 3.0853 	Acc: 41
# 	Validation Loss: 2.951162815093994 	 Validation Acc: 47.92820739746094
# Epoch: 15 	Step: 150000 	Loss: 3.1185 	Acc: 49
# 	Validation Loss: 2.9512906074523926 	 Validation Acc: 47.96666717529297
# Epoch: 16 	Step: 151000 	Loss: 3.0500 	Acc: 44
# 	Validation Loss: 2.9478087425231934 	 Validation Acc: 47.93077087402344
# Epoch: 16 	Step: 152000 	Loss: 2.8467 	Acc: 51
# 	Validation Loss: 2.9353742599487305 	 Validation Acc: 48.117950439453125
# Epoch: 16 	Step: 153000 	Loss: 3.2158 	Acc: 38
# 	Validation Loss: 2.949798107147217 	 Validation Acc: 48.012821197509766
# Epoch: 16 	Step: 154000 	Loss: 3.2675 	Acc: 41
# 	Validation Loss: 3.008523464202881 	 Validation Acc: 46.79487228393555
# Epoch: 16 	Step: 155000 	Loss: 2.6228 	Acc: 57
# 	Validation Loss: 2.9461729526519775 	 Validation Acc: 47.93589782714844
# Epoch: 16 	Step: 156000 	Loss: 3.0712 	Acc: 43
# 	Validation Loss: 3.0622854232788086 	 Validation Acc: 46.366668701171875
# Epoch: 16 	Step: 157000 	Loss: 2.4513 	Acc: 61
# 	Validation Loss: 2.9499735832214355 	 Validation Acc: 48.35641098022461
# Epoch: 16 	Step: 158000 	Loss: 2.9467 	Acc: 53
# 	Validation Loss: 2.9926841259002686 	 Validation Acc: 47.35641098022461
# Epoch: 16 	Step: 159000 	Loss: 2.7852 	Acc: 54
# 	Validation Loss: 3.0090558528900146 	 Validation Acc: 46.88718032836914
# Epoch: 16 	Step: 160000 	Loss: 3.2147 	Acc: 40
# 	Validation Loss: 2.927518606185913 	 Validation Acc: 48.861541748046875
# Epoch: 17 	Step: 161000 	Loss: 2.5748 	Acc: 60
# 	Validation Loss: 2.972346067428589 	 Validation Acc: 47.982051849365234
# Epoch: 17 	Step: 162000 	Loss: 2.7299 	Acc: 48
# 	Validation Loss: 2.973817825317383 	 Validation Acc: 47.66410446166992
# Epoch: 17 	Step: 163000 	Loss: 3.1435 	Acc: 40
# 	Validation Loss: 2.9909775257110596 	 Validation Acc: 47.63333511352539
# Epoch: 17 	Step: 164000 	Loss: 2.7311 	Acc: 55
# 	Validation Loss: 2.9523911476135254 	 Validation Acc: 47.78461837768555
# Epoch: 17 	Step: 165000 	Loss: 2.8505 	Acc: 48
# 	Validation Loss: 3.003911018371582 	 Validation Acc: 47.087181091308594
# Epoch: 17 	Step: 166000 	Loss: 3.0929 	Acc: 49
# 	Validation Loss: 3.0147945880889893 	 Validation Acc: 46.67179489135742
# Epoch: 17 	Step: 167000 	Loss: 3.1417 	Acc: 42
# 	Validation Loss: 3.0694453716278076 	 Validation Acc: 45.85897445678711
# Epoch: 17 	Step: 168000 	Loss: 3.0589 	Acc: 45
# 	Validation Loss: 3.024155616760254 	 Validation Acc: 46.56666946411133
# Epoch: 17 	Step: 169000 	Loss: 2.8982 	Acc: 47
# 	Validation Loss: 3.0204455852508545 	 Validation Acc: 46.330772399902344
# Epoch: 17 	Step: 170000 	Loss: 2.6953 	Acc: 52
# 	Validation Loss: 2.973666191101074 	 Validation Acc: 47.866668701171875
# Epoch: 18 	Step: 171000 	Loss: 2.9378 	Acc: 45
# 	Validation Loss: 2.975525379180908 	 Validation Acc: 47.730770111083984
# Epoch: 18 	Step: 172000 	Loss: 3.1623 	Acc: 40
# 	Validation Loss: 3.054469108581543 	 Validation Acc: 46.374359130859375
# Epoch: 18 	Step: 173000 	Loss: 3.1331 	Acc: 46
# 	Validation Loss: 3.029174566268921 	 Validation Acc: 46.653846740722656
# Epoch: 18 	Step: 174000 	Loss: 2.7927 	Acc: 49
# 	Validation Loss: 2.9860613346099854 	 Validation Acc: 47.60256576538086
# Epoch: 18 	Step: 175000 	Loss: 2.7565 	Acc: 43
# 	Validation Loss: 3.017253875732422 	 Validation Acc: 46.71794891357422
# Epoch: 18 	Step: 176000 	Loss: 2.8893 	Acc: 48
# 	Validation Loss: 3.0087454319000244 	 Validation Acc: 47.32564163208008
# Epoch: 18 	Step: 177000 	Loss: 2.7804 	Acc: 44
# 	Validation Loss: 3.031071662902832 	 Validation Acc: 46.78461837768555
# Epoch: 18 	Step: 178000 	Loss: 2.9498 	Acc: 54
# 	Validation Loss: 3.0166423320770264 	 Validation Acc: 46.88974380493164
# Epoch: 18 	Step: 179000 	Loss: 3.1071 	Acc: 47
# 	Validation Loss: 3.057079792022705 	 Validation Acc: 45.9871826171875
# Epoch: 18 	Step: 180000 	Loss: 2.6584 	Acc: 52
# 	Validation Loss: 2.9616363048553467 	 Validation Acc: 47.68205261230469
# Epoch: 19 	Step: 181000 	Loss: 2.8864 	Acc: 49
# 	Validation Loss: 2.9880340099334717 	 Validation Acc: 47.43589782714844
# Epoch: 19 	Step: 182000 	Loss: 3.0127 	Acc: 56
# 	Validation Loss: 3.1247403621673584 	 Validation Acc: 44.80513000488281
# Epoch: 19 	Step: 183000 	Loss: 3.1143 	Acc: 47
# 	Validation Loss: 3.0385520458221436 	 Validation Acc: 45.876922607421875
# Epoch: 19 	Step: 184000 	Loss: 3.3567 	Acc: 45
# 	Validation Loss: 3.0241825580596924 	 Validation Acc: 46.643592834472656
# Epoch: 19 	Step: 185000 	Loss: 2.9799 	Acc: 44
# 	Validation Loss: 3.1555182933807373 	 Validation Acc: 44.228206634521484
# Epoch: 19 	Step: 186000 	Loss: 2.6923 	Acc: 47
# 	Validation Loss: 3.0083277225494385 	 Validation Acc: 46.77948760986328
# Epoch: 19 	Step: 187000 	Loss: 2.9522 	Acc: 51
# 	Validation Loss: 3.036853551864624 	 Validation Acc: 46.646156311035156
# Epoch: 19 	Step: 188000 	Loss: 2.7679 	Acc: 48
# 	Validation Loss: 3.002819299697876 	 Validation Acc: 46.82564163208008
# Epoch: 19 	Step: 189000 	Loss: 3.0041 	Acc: 48
# 	Validation Loss: 3.0098235607147217 	 Validation Acc: 47.26923370361328
# Epoch: 19 	Step: 190000 	Loss: 2.8595 	Acc: 45
# 	Validation Loss: 3.032278537750244 	 Validation Acc: 46.4487190246582
# Epoch: 20 	Step: 191000 	Loss: 2.5711 	Acc: 53
# 	Validation Loss: 2.976954698562622 	 Validation Acc: 47.29487228393555
# Epoch: 20 	Step: 192000 	Loss: 3.1340 	Acc: 34
# 	Validation Loss: 3.0710058212280273 	 Validation Acc: 46.11025619506836
# Epoch: 20 	Step: 193000 	Loss: 2.7702 	Acc: 48
# 	Validation Loss: 3.066286087036133 	 Validation Acc: 45.725643157958984
# Epoch: 20 	Step: 194000 	Loss: 3.2195 	Acc: 46
# 	Validation Loss: 3.0210580825805664 	 Validation Acc: 46.91025924682617
# Epoch: 20 	Step: 195000 	Loss: 3.5061 	Acc: 41
# 	Validation Loss: 3.07635498046875 	 Validation Acc: 45.66154098510742
# Epoch: 20 	Step: 196000 	Loss: 3.2231 	Acc: 39
# 	Validation Loss: 3.0976107120513916 	 Validation Acc: 45.31795120239258
# Epoch: 20 	Step: 197000 	Loss: 2.8164 	Acc: 45
# 	Validation Loss: 3.119129180908203 	 Validation Acc: 45.43846130371094
# Epoch: 20 	Step: 198000 	Loss: 3.3350 	Acc: 42
# 	Validation Loss: 3.0220935344696045 	 Validation Acc: 47.0461540222168
# Epoch: 20 	Step: 199000 	Loss: 3.2324 	Acc: 40
# 	Validation Loss: 3.0469415187835693 	 Validation Acc: 46.38461685180664
# Epoch: 20 	Step: 200000 	Loss: 3.2176 	Acc: 48
# 	Validation Loss: 3.1582815647125244 	 Validation Acc: 44.084617614746094
# Epoch: 21 	Step: 201000 	Loss: 2.9947 	Acc: 53
# 	Validation Loss: 3.087165117263794 	 Validation Acc: 45.505130767822266
# Epoch: 21 	Step: 202000 	Loss: 2.8662 	Acc: 47
# 	Validation Loss: 3.1302168369293213 	 Validation Acc: 44.4974365234375
# Epoch: 21 	Step: 203000 	Loss: 2.8529 	Acc: 45
# 	Validation Loss: 3.132814407348633 	 Validation Acc: 44.725643157958984
# Epoch: 21 	Step: 204000 	Loss: 3.1133 	Acc: 50
# 	Validation Loss: 3.085569143295288 	 Validation Acc: 45.646156311035156
# Epoch: 21 	Step: 205000 	Loss: 2.9703 	Acc: 44
# 	Validation Loss: 3.0170047283172607 	 Validation Acc: 46.65897750854492
# Epoch: 21 	Step: 206000 	Loss: 3.1039 	Acc: 43
# 	Validation Loss: 3.0128273963928223 	 Validation Acc: 46.874359130859375
# Epoch: 21 	Step: 207000 	Loss: 3.0198 	Acc: 44
# 	Validation Loss: 3.174135684967041 	 Validation Acc: 43.96410369873047
# Epoch: 21 	Step: 208000 	Loss: 3.2348 	Acc: 42
# 	Validation Loss: 3.0995888710021973 	 Validation Acc: 45.32564163208008
# Epoch: 21 	Step: 209000 	Loss: 3.0904 	Acc: 44
# 	Validation Loss: 3.078629970550537 	 Validation Acc: 45.88461685180664
# Epoch: 21 	Step: 210000 	Loss: 3.1678 	Acc: 47
# 	Validation Loss: 3.084700584411621 	 Validation Acc: 45.376922607421875
# Epoch: 22 	Step: 211000 	Loss: 2.7133 	Acc: 45
# 	Validation Loss: 3.1118369102478027 	 Validation Acc: 45.0461540222168
# Epoch: 22 	Step: 212000 	Loss: 2.7729 	Acc: 62
# 	Validation Loss: 3.098557710647583 	 Validation Acc: 45.25128173828125
# Epoch: 22 	Step: 213000 	Loss: 2.8034 	Acc: 54
# 	Validation Loss: 3.155579090118408 	 Validation Acc: 44.38974380493164
# Epoch: 22 	Step: 214000 	Loss: 3.0867 	Acc: 44
# 	Validation Loss: 3.20991587638855 	 Validation Acc: 43.34615707397461
# Epoch: 22 	Step: 215000 	Loss: 3.5303 	Acc: 34
# 	Validation Loss: 3.104341506958008 	 Validation Acc: 45.21538543701172
# Epoch: 22 	Step: 216000 	Loss: 2.9710 	Acc: 48
# 	Validation Loss: 3.182133913040161 	 Validation Acc: 44.13846206665039
# Epoch: 22 	Step: 217000 	Loss: 2.7199 	Acc: 51
# 	Validation Loss: 3.108222007751465 	 Validation Acc: 45.51795196533203
# Epoch: 22 	Step: 218000 	Loss: 3.0396 	Acc: 47
# 	Validation Loss: 3.1935157775878906 	 Validation Acc: 43.46154022216797
# Epoch: 22 	Step: 219000 	Loss: 3.2303 	Acc: 40
# 	Validation Loss: 3.1512978076934814 	 Validation Acc: 44.333335876464844
# Epoch: 22 	Step: 220000 	Loss: 3.4684 	Acc: 34
# 	Validation Loss: 3.1085312366485596 	 Validation Acc: 44.974361419677734
# Epoch: 23 	Step: 221000 	Loss: 3.3394 	Acc: 41
# 	Validation Loss: 3.1257522106170654 	 Validation Acc: 44.79487228393555
# Epoch: 23 	Step: 222000 	Loss: 3.1097 	Acc: 50
# 	Validation Loss: 3.0997490882873535 	 Validation Acc: 45.48974609375
# Epoch: 23 	Step: 223000 	Loss: 3.6016 	Acc: 37
# 	Validation Loss: 3.2315752506256104 	 Validation Acc: 42.4974365234375
# Epoch: 23 	Step: 224000 	Loss: 3.0099 	Acc: 43
# 	Validation Loss: 3.178680896759033 	 Validation Acc: 43.653846740722656
# Epoch: 23 	Step: 225000 	Loss: 2.5880 	Acc: 55
# 	Validation Loss: 3.071744918823242 	 Validation Acc: 45.869232177734375
# Epoch: 23 	Step: 226000 	Loss: 3.0377 	Acc: 43
# 	Validation Loss: 3.2121798992156982 	 Validation Acc: 42.85641098022461
# Epoch: 23 	Step: 227000 	Loss: 3.4245 	Acc: 28
# 	Validation Loss: 3.1407470703125 	 Validation Acc: 44.38461685180664
# Epoch: 23 	Step: 228000 	Loss: 3.4265 	Acc: 37
# 	Validation Loss: 3.1892738342285156 	 Validation Acc: 43.31025695800781
# Epoch: 23 	Step: 229000 	Loss: 3.0277 	Acc: 39
# 	Validation Loss: 3.20774245262146 	 Validation Acc: 43.4435920715332
# Epoch: 23 	Step: 230000 	Loss: 3.5329 	Acc: 42
# 	Validation Loss: 3.077873706817627 	 Validation Acc: 45.70769500732422
# Epoch: 24 	Step: 231000 	Loss: 3.2210 	Acc: 37
# 	Validation Loss: 3.161886215209961 	 Validation Acc: 43.78974533081055
# Epoch: 24 	Step: 232000 	Loss: 2.6317 	Acc: 52
# 	Validation Loss: 3.1746013164520264 	 Validation Acc: 44.06666946411133
# Epoch: 24 	Step: 233000 	Loss: 3.3406 	Acc: 37
# 	Validation Loss: 3.219963312149048 	 Validation Acc: 43.03333282470703
# Epoch: 24 	Step: 234000 	Loss: 3.5252 	Acc: 35
# 	Validation Loss: 3.2432234287261963 	 Validation Acc: 42.646156311035156
# Epoch: 24 	Step: 235000 	Loss: 2.8273 	Acc: 49
# 	Validation Loss: 3.090224027633667 	 Validation Acc: 45.735897064208984
